# %% [markdown]
# # Bloco jupyter para treinamento e compilação de modelo usando framework aXeleRate
#
#
# ---
#
# Emerson Klippel - 15/07/2020

# %% [markdown]
# Criando a conexão com o Google Drive e montando a drive na máquina virtual do Google Colab.
# Nesse ponto é necessário conectar o bloco de notas ao processamento remoto e selecionar o uso de GPU

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importando e instalado o framework aXeleRate no VM do Google Colab

# %%
# %tensorflow_version 1.x
# !git clone https://github.com/AIWintermuteAI/aXeleRate.git
import sys
sys.path.append('/content/aXeleRate')
from axelerate import setup_training,setup_inference
# Out:
# TensorFlow 1.x selected.
# Cloning into 'aXeleRate'...
# remote: Enumerating objects: 1495, done.
# remote: Total 1495 (delta 0), reused 0 (delta 0), pack-reused 1495
# Receiving objects: 100% (1495/1495), 2.02 MiB | 12.04 MiB/s, done.
# Resolving deltas: 100% (920/920), done.
# Using TensorFlow backend.

# %% [markdown]
# No próximo passo o dicionário com as configurações do treinamento são definidos

# %%
config = {
        "model" : {
            "type":                 "Classifier",
            "architecture":         "MobileNet7_5",
            "input_size":           224,
            "fully-connected":      [100,50],
            "labels":               [],
            "dropout" : 		0.5
        },
        "weights" : {
            "full":   				"",
            "backend":   		    "imagenet",
            "save_bottleneck":      False
        
        },
        "train" : {
            "actual_epoch":         10,
            "train_image_folder":   "drive/My Drive/Modelo_Teste/Treinamento",
            "train_times":          4,
            "valid_image_folder":   "drive/My Drive/Modelo_Teste/Validacao",
            "valid_times":          4,
            "valid_metric":         "val_accuracy",
            "batch_size":           4,
            "learning_rate":        1e-3,
            "saved_folder":   		"classifier",
            "first_trainable_layer": "",
            "augumentation":				True
        },
        "converter" : {
            "type":   				["k210","tflite"]
        }
    }

# %% [markdown]
# Treinamento e compilação do modelo a partir das configurações do dicionário definido anteriormente

# %%
model_path = setup_training(config_dict=config)
# Out:
# Project folder projects/classifier is created.
# Tflite Converter ready
# Downloading K210 Converter
# Downloading data from https://github.com/kendryte/nncase/releases/download/v0.2.0-beta2/ncc_linux_x86_64.tar.xz
# 7397376/7392744 [==============================] - 0s 0us/step
# /content/aXeleRate/axelerate/networks/common_utils/ncc_linux_x86_64.tar.xz
# Classifier
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_7_5_224_tf_no_top.h5
# 10633216/10626956 [==============================] - 0s 0us/step
# Successfully loaded imagenet backend weights
# Failed to load pre-trained weights for the whole model. It might be because you didn't specify any or the weight file cannot be found
# Found 60 images belonging to 3 classes.
# Found 6 images belonging to 3 classes.
# Bobina_Tesla_Klippel
# Sem_Classificacao
# Use_Less_Klippel
# Current training session folder is projects/classifier/2020-07-15_14-25-32
#
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 226, 226, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 24)      648
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 24)      96
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 24)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 24)      216
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 24)      96
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 24)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 48)      1152
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 48)      192
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 48)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 114, 114, 48)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 48)        432
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 48)        192
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 48)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 96)        4608
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 96)        384
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 96)        0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 96)        864
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 96)        384
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 96)        0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 96)        9216
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 96)        384
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 96)        0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 58, 58, 96)        0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 96)        864
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 96)        384
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 96)        0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 192)       18432
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 192)       768
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 192)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 192)       1728
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 192)       768
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 192)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 192)       36864
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 192)       768
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 192)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 30, 30, 192)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 192)       1728
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 192)       768
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 192)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 384)       73728
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 384)       3456
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 384)       147456
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 384)       3456
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 384)       147456
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 384)       3456
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 384)       147456
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 384)       3456
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 384)       147456
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 384)       3456
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 384)       147456
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 384)       1536
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 384)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 16, 16, 384)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 384)         3456
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 384)         1536
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 384)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 768)         294912
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 768)         3072
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 768)         0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 768)         6912
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 768)         3072
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 768)         0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 768)         589824
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 768)         3072
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 768)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               76900
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 153
# =================================================================
# Total params: 1,915,079
# Trainable params: 1,898,663
# Non-trainable params: 16,416
# _________________________________________________________________
# Epoch 1/10
# 15/15 [==============================] - 30s 2s/step - loss: 1.4187 - accuracy: 0.4333 - val_loss: 0.4328 - val_accuracy: 0.3333
#
# Epoch 00001: val_accuracy improved from -inf to 0.33333, saving model to projects/classifier/2020-07-15_14-25-32/Classifier_best_val_accuracy.h5
# Epoch 2/10
# 15/15 [==============================] - 8s 511ms/step - loss: 1.0328 - accuracy: 0.6667 - val_loss: 1.7611 - val_accuracy: 0.6667
#
# Epoch 00002: val_accuracy improved from 0.33333 to 0.66667, saving model to projects/classifier/2020-07-15_14-25-32/Classifier_best_val_accuracy.h5
# Epoch 3/10
# 15/15 [==============================] - 10s 649ms/step - loss: 0.9637 - accuracy: 0.6333 - val_loss: 0.2919 - val_accuracy: 0.8333
#
# Epoch 00003: val_accuracy improved from 0.66667 to 0.83333, saving model to projects/classifier/2020-07-15_14-25-32/Classifier_best_val_accuracy.h5
# Epoch 4/10
# 15/15 [==============================] - 10s 641ms/step - loss: 0.7255 - accuracy: 0.7500 - val_loss: 0.4482 - val_accuracy: 0.6667
#
# Epoch 00004: val_accuracy did not improve from 0.83333
# Epoch 5/10
# 15/15 [==============================] - 11s 709ms/step - loss: 0.5291 - accuracy: 0.7833 - val_loss: 1.2278 - val_accuracy: 0.8333
#
# Epoch 00005: val_accuracy did not improve from 0.83333
# Epoch 6/10
# 15/15 [==============================] - 11s 706ms/step - loss: 0.5098 - accuracy: 0.8667 - val_loss: 0.5064 - val_accuracy: 0.8333
#
# Epoch 00006: val_accuracy did not improve from 0.83333
# Epoch 7/10
# 15/15 [==============================] - 11s 717ms/step - loss: 0.3430 - accuracy: 0.9000 - val_loss: 0.2280 - val_accuracy: 1.0000
#
# Epoch 00007: val_accuracy improved from 0.83333 to 1.00000, saving model to projects/classifier/2020-07-15_14-25-32/Classifier_best_val_accuracy.h5
# Epoch 8/10
# 15/15 [==============================] - 10s 641ms/step - loss: 0.4835 - accuracy: 0.8500 - val_loss: 0.0065 - val_accuracy: 1.0000
#
# Epoch 00008: val_accuracy did not improve from 1.00000
# Epoch 9/10
# 15/15 [==============================] - 11s 701ms/step - loss: 0.3693 - accuracy: 0.8500 - val_loss: 0.0048 - val_accuracy: 1.0000
#
# Epoch 00009: val_accuracy did not improve from 1.00000
# Epoch 10/10
# 15/15 [==============================] - 11s 706ms/step - loss: 0.9875 - accuracy: 0.7167 - val_loss: 0.0477 - val_accuracy: 1.0000
#
# Epoch 00010: val_accuracy did not improve from 1.00000
# 2-mins to train
# ['drive/My Drive/Modelo_Teste/Validacao/Sem_Classificacao/20200715_092103.jpg', 'drive/My Drive/Modelo_Teste/Validacao/Sem_Classificacao/20200715_092133.jpg', 'drive/My Drive/Modelo_Teste/Validacao/Use_Less_Klippel/20200715_092121.jpg', 'drive/My Drive/Modelo_Teste/Validacao/Use_Less_Klippel/20200715_092130.jpg', 'drive/My Drive/Modelo_Teste/Validacao/Bobina_Tesla_Klippel/20200715_092051.jpg', 'drive/My Drive/Modelo_Teste/Validacao/Bobina_Tesla_Klippel/20200715_092058.jpg']
# projects/classifier/2020-07-15_14-25-32/Classifier_best_val_accuracy.kmodel
# 0

# %% [markdown]
# Verificação do modelo a partir do .h5

# %%
from keras import backend as K 
K.clear_session()
setup_inference(config, model_path)
# Out:
# Folder projects/classifier/2020-07-15_14-25-32/Inference_results is created.
# Classifier
# Loading pre-trained weights for the whole model:  projects/classifier/2020-07-15_14-25-32/Classifier_best_val_accuracy.h5
# (4608, 2240, 3)
# projects/classifier/2020-07-15_14-25-32/Inference_results/20200715_092103.jpg
# Sem_Classificacao:0.9977567791938782
# (4608, 2240, 3)
# projects/classifier/2020-07-15_14-25-32/Inference_results/20200715_092133.jpg
# Sem_Classificacao:0.9964622855186462
# (4608, 2240, 3)
# projects/classifier/2020-07-15_14-25-32/Inference_results/20200715_092121.jpg
# Use_Less_Klippel:0.9999903440475464
# (4608, 2240, 3)
# projects/classifier/2020-07-15_14-25-32/Inference_results/20200715_092130.jpg
# Use_Less_Klippel:0.9997993111610413
# (4608, 2240, 3)
# projects/classifier/2020-07-15_14-25-32/Inference_results/20200715_092051.jpg
# Bobina_Tesla_Klippel:0.9664738178253174
# (4608, 2240, 3)
# projects/classifier/2020-07-15_14-25-32/Inference_results/20200715_092058.jpg
# Bobina_Tesla_Klippel:0.9612888097763062
# Average prediction time:9.599924087524414 ms
